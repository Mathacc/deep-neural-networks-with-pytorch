# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0110ENSkillsNetwork952-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#LR_Loader_Cost">Create a Linear Regression Object, Data Loader and Criterion Function</a></li>
#     <li><a href="#LR_Hyper">Different learning rates and Data Structures to Store results for Different Hyperparameters</a></li>
#     <li><a href="#Model">Train different modules for different Hyperparameters</a></li>
#     <li><a href="#Result">View Results</a></li>
# </ul>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# Import libraries we need for this lab, and set the random seed

from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    
    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]
            
            #outliers 
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass
      
    # Getter
    def __getitem__(self, index):    
        return self.x[index], self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2>

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2>

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model">Train different models  for different Hyperparameters</h2>

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):
    
    # iterate through different learning rates 
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()
    
        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Result">View the Results</h2>

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[1.9380242]
#  [1.8859648]
#  [1.8339052]]
# 1 [[5.787894]
#  [5.669733]
#  [5.551572]]
# 2 [[6.591426 ]
#  [6.4579716]
#  [6.3245163]]
# 3 [[13.874804]
#  [13.460467]
#  [13.046129]]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

#Type your code here: 
for i, sample in enumerate(trainloader):
    yhat = good_model(sample[0])
    print(f"predicted: {yhat} target: {sample[1]}")
# Out:
# predicted: tensor([[13.8748]], grad_fn=<AddmmBackward0>) target: tensor([[0.]])
# predicted: tensor([[13.4605]], grad_fn=<AddmmBackward0>) target: tensor([[9.7682]])
# predicted: tensor([[13.0461]], grad_fn=<AddmmBackward0>) target: tensor([[9.3972]])
# predicted: tensor([[12.6318]], grad_fn=<AddmmBackward0>) target: tensor([[9.1585]])
# predicted: tensor([[12.2175]], grad_fn=<AddmmBackward0>) target: tensor([[8.8503]])
# predicted: tensor([[11.8031]], grad_fn=<AddmmBackward0>) target: tensor([[8.5768]])
# predicted: tensor([[11.3888]], grad_fn=<AddmmBackward0>) target: tensor([[8.1366]])
# predicted: tensor([[10.9744]], grad_fn=<AddmmBackward0>) target: tensor([[7.8402]])
# predicted: tensor([[10.5601]], grad_fn=<AddmmBackward0>) target: tensor([[7.5289]])
# predicted: tensor([[10.1458]], grad_fn=<AddmmBackward0>) target: tensor([[7.2914]])
# predicted: tensor([[9.7314]], grad_fn=<AddmmBackward0>) target: tensor([[7.1114]])
# predicted: tensor([[9.3171]], grad_fn=<AddmmBackward0>) target: tensor([[6.7356]])
# predicted: tensor([[8.9028]], grad_fn=<AddmmBackward0>) target: tensor([[6.3636]])
# predicted: tensor([[8.4884]], grad_fn=<AddmmBackward0>) target: tensor([[6.2133]])
# predicted: tensor([[8.0741]], grad_fn=<AddmmBackward0>) target: tensor([[5.7439]])
# predicted: tensor([[7.6597]], grad_fn=<AddmmBackward0>) target: tensor([[5.7347]])
# predicted: tensor([[7.2454]], grad_fn=<AddmmBackward0>) target: tensor([[5.2898]])
# predicted: tensor([[6.8311]], grad_fn=<AddmmBackward0>) target: tensor([[4.7818]])
# predicted: tensor([[6.4167]], grad_fn=<AddmmBackward0>) target: tensor([[4.6719]])
# predicted: tensor([[6.0024]], grad_fn=<AddmmBackward0>) target: tensor([[4.3731]])
# predicted: tensor([[5.5881]], grad_fn=<AddmmBackward0>) target: tensor([[4.1097]])
# predicted: tensor([[5.1737]], grad_fn=<AddmmBackward0>) target: tensor([[3.6799]])
# predicted: tensor([[4.7594]], grad_fn=<AddmmBackward0>) target: tensor([[3.4405]])
# predicted: tensor([[4.3451]], grad_fn=<AddmmBackward0>) target: tensor([[3.1276]])
# predicted: tensor([[3.9307]], grad_fn=<AddmmBackward0>) target: tensor([[2.7926]])
# predicted: tensor([[3.5164]], grad_fn=<AddmmBackward0>) target: tensor([[2.5096]])
# predicted: tensor([[3.1020]], grad_fn=<AddmmBackward0>) target: tensor([[2.3065]])
# predicted: tensor([[2.6877]], grad_fn=<AddmmBackward0>) target: tensor([[1.8941]])
# predicted: tensor([[2.2734]], grad_fn=<AddmmBackward0>) target: tensor([[1.4781]])
# predicted: tensor([[1.8590]], grad_fn=<AddmmBackward0>) target: tensor([[1.3612]])
# predicted: tensor([[1.4447]], grad_fn=<AddmmBackward0>) target: tensor([[0.9574]])
# predicted: tensor([[1.0304]], grad_fn=<AddmmBackward0>) target: tensor([[0.6138]])
# predicted: tensor([[0.6160]], grad_fn=<AddmmBackward0>) target: tensor([[0.4370]])
# predicted: tensor([[0.2017]], grad_fn=<AddmmBackward0>) target: tensor([[0.0611]])
# predicted: tensor([[-0.2127]], grad_fn=<AddmmBackward0>) target: tensor([[-0.2928]])
# predicted: tensor([[-0.6270]], grad_fn=<AddmmBackward0>) target: tensor([[-0.5406]])
# predicted: tensor([[-1.0413]], grad_fn=<AddmmBackward0>) target: tensor([[-0.8006]])
# predicted: tensor([[-1.4557]], grad_fn=<AddmmBackward0>) target: tensor([[-1.1196]])
# predicted: tensor([[-1.8700]], grad_fn=<AddmmBackward0>) target: tensor([[-1.2406]])
# predicted: tensor([[-2.2843]], grad_fn=<AddmmBackward0>) target: tensor([[-1.7636]])
# predicted: tensor([[-2.6987]], grad_fn=<AddmmBackward0>) target: tensor([[-1.9931]])
# predicted: tensor([[-3.1130]], grad_fn=<AddmmBackward0>) target: tensor([[-2.2683]])
# predicted: tensor([[-3.5273]], grad_fn=<AddmmBackward0>) target: tensor([[-2.6185]])
# predicted: tensor([[-3.9417]], grad_fn=<AddmmBackward0>) target: tensor([[-2.9013]])
# predicted: tensor([[-4.3560]], grad_fn=<AddmmBackward0>) target: tensor([[-3.3132]])
# predicted: tensor([[-4.7704]], grad_fn=<AddmmBackward0>) target: tensor([[-3.6087]])
# predicted: tensor([[-5.1847]], grad_fn=<AddmmBackward0>) target: tensor([[-3.8484]])
# predicted: tensor([[-5.5990]], grad_fn=<AddmmBackward0>) target: tensor([[-3.9500]])
# predicted: tensor([[-6.0134]], grad_fn=<AddmmBackward0>) target: tensor([[-4.4355]])
# predicted: tensor([[-6.4277]], grad_fn=<AddmmBackward0>) target: tensor([[-4.7463]])
# predicted: tensor([[-6.8420]], grad_fn=<AddmmBackward0>) target: tensor([[20.]])
# predicted: tensor([[-7.2564]], grad_fn=<AddmmBackward0>) target: tensor([[20.]])
# predicted: tensor([[-7.6707]], grad_fn=<AddmmBackward0>) target: tensor([[20.]])
# predicted: tensor([[-8.0851]], grad_fn=<AddmmBackward0>) target: tensor([[20.]])
# predicted: tensor([[-8.4994]], grad_fn=<AddmmBackward0>) target: tensor([[20.]])
# predicted: tensor([[-8.9137]], grad_fn=<AddmmBackward0>) target: tensor([[-6.4679]])
# predicted: tensor([[-9.3281]], grad_fn=<AddmmBackward0>) target: tensor([[-6.8337]])
# predicted: tensor([[-9.7424]], grad_fn=<AddmmBackward0>) target: tensor([[-7.0345]])
# predicted: tensor([[-10.1567]], grad_fn=<AddmmBackward0>) target: tensor([[-7.4026]])
# predicted: tensor([[-10.5711]], grad_fn=<AddmmBackward0>) target: tensor([[-7.4903]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# for x, y in trainloader:
#     print("yhat= ", model(x),"y", y)
# -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0110ENSkillsNetwork952-2023-01-01&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0110ENSkillsNetwork952-2023-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0110ENSkillsNetwork952-2023-01-01">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
